# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#Reading in the csv files
csv_file1 = "Resources/netflix_titles.csv"
csv_file2 = "Resources/movie_metadata.csv"
netflix_movies = pd.read_csv(csv_file1)
other_movies = pd.read_csv(csv_file2)
#Showing the first few rows of each file
netflix_movies.head()
#other_movies.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 1                            United Kingdom  September 9, 2016          2016
# 2                             United States  September 8, 2018          2013
# 3                             United States  September 8, 2018          2016
# 4                             United States  September 8, 2017          2017
#
#      rating  duration                           listed_in  \
# 0     TV-PG    90 min  Children & Family Movies, Comedies
# 1     TV-MA    94 min                     Stand-Up Comedy
# 2  TV-Y7-FV  1 Season                            Kids' TV
# 3     TV-Y7  1 Season                            Kids' TV
# 4     TV-14    99 min                            Comedies
#
#                                          description
# 0  Before planning an awesome wedding for his gra...
# 1  Jandino Asporaat riffs on the challenges of ra...
# 2  With the help of three human allies, the Autob...
# 3  When a prison ship crash unleashes hundreds of...
# 4  When nerdy high schooler Dani finally attracts...

# %%
new_netflix_movies = netflix_movies[['title', 'type', 'country', 'director', 'release_year', 'rating']]
new_netflix_movies.head()
# Out:
#                                      title     type  \
# 0  Norm of the North: King Sized Adventure    Movie
# 1               Jandino: Whatever it Takes    Movie
# 2                       Transformers Prime  TV Show
# 3         Transformers: Robots in Disguise  TV Show
# 4                             #realityhigh    Movie
#
#                                     country                  director  \
# 0  United States, India, South Korea, China  Richard Finn, Tim Maltby
# 1                            United Kingdom                       NaN
# 2                             United States                       NaN
# 3                             United States                       NaN
# 4                             United States          Fernando Lebrija
#
#    release_year    rating
# 0          2019     TV-PG
# 1          2016     TV-MA
# 2          2013  TV-Y7-FV
# 3          2016     TV-Y7
# 4          2017     TV-14

# %%
cleaned_netflix = new_netflix_movies[new_netflix_movies.type != 'TV Show']
cleaned_netflix.head()
# Out:
#                                      title   type  \
# 0  Norm of the North: King Sized Adventure  Movie
# 1               Jandino: Whatever it Takes  Movie
# 4                             #realityhigh  Movie
# 6                                 Automata  Movie
# 7       Fabrizio Copano: Solo pienso en mi  Movie
#
#                                     country                         director  \
# 0  United States, India, South Korea, China         Richard Finn, Tim Maltby
# 1                            United Kingdom                              NaN
# 4                             United States                 Fernando Lebrija
# 6    Bulgaria, United States, Spain, Canada                      Gabe Ibáñez
# 7                                     Chile  Rodrigo Toro, Francisco Schultz
#
#    release_year rating
# 0          2019  TV-PG
# 1          2016  TV-MA
# 4          2017  TV-14
# 6          2014      R
# 7          2017  TV-MA

# %%
new_other_movies = other_movies[['movie_title', 'genres', 'director_name', 'title_year', 'country', 'budget', 'gross', 'imdb_score', 'content_rating']]
new_other_movies.head()
# Out:
#                                          movie_title  \
# 0                                            Avatar
# 1          Pirates of the Caribbean: At World's End
# 2                                           Spectre
# 3                             The Dark Knight Rises
# 4  Star Wars: Episode VII - The Force Awakens    ...
#
#                             genres      director_name  title_year country  \
# 0  Action|Adventure|Fantasy|Sci-Fi      James Cameron      2009.0     USA
# 1         Action|Adventure|Fantasy     Gore Verbinski      2007.0     USA
# 2        Action|Adventure|Thriller         Sam Mendes      2015.0      UK
# 3                  Action|Thriller  Christopher Nolan      2012.0     USA
# 4                      Documentary        Doug Walker         NaN     NaN
#
#         budget        gross  imdb_score content_rating
# 0  237000000.0  760505847.0         7.9          PG-13
# 1  300000000.0  309404152.0         7.1          PG-13
# 2  245000000.0  200074175.0         6.8          PG-13
# 3  250000000.0  448130642.0         8.5          PG-13
# 4          NaN          NaN         7.1            NaN

# %%
new_other_movies.rename(columns={'movie_title': 'title', 'director_name': 'director', 'title_year': 'release_year', 'content_rating':'rating'},inplace=True)
cleaned_other_movies = new_other_movies
cleaned_other_movies.head()
# Out:
#                                                title  \
# 0                                            Avatar
# 1          Pirates of the Caribbean: At World's End
# 2                                           Spectre
# 3                             The Dark Knight Rises
# 4  Star Wars: Episode VII - The Force Awakens    ...
#
#                             genres           director  release_year country  \
# 0  Action|Adventure|Fantasy|Sci-Fi      James Cameron        2009.0     USA
# 1         Action|Adventure|Fantasy     Gore Verbinski        2007.0     USA
# 2        Action|Adventure|Thriller         Sam Mendes        2015.0      UK
# 3                  Action|Thriller  Christopher Nolan        2012.0     USA
# 4                      Documentary        Doug Walker           NaN     NaN
#
#         budget        gross  imdb_score rating
# 0  237000000.0  760505847.0         7.9  PG-13
# 1  300000000.0  309404152.0         7.1  PG-13
# 2  245000000.0  200074175.0         6.8  PG-13
# 3  250000000.0  448130642.0         8.5  PG-13
# 4          NaN          NaN         7.1    NaN

# %%
cleaned_netflix.set_index(['title'])
# Out:
#                                           type  \
# title
# Norm of the North: King Sized Adventure  Movie
# Jandino: Whatever it Takes               Movie
# #realityhigh                             Movie
# Automata                                 Movie
# Fabrizio Copano: Solo pienso en mi       Movie
# ...                                        ...
# Frank and Cindy                          Movie
# Frank and Cindy                          Movie
# Iverson                                  Movie
# Jeremy Scott: The People's Designer      Movie
# Little Baby Bum: Nursery Rhyme Friends   Movie
#
#                                                                           country  \
# title
# Norm of the North: King Sized Adventure  United States, India, South Korea, China
# Jandino: Whatever it Takes                                         United Kingdom
# #realityhigh                                                        United States
# Automata                                   Bulgaria, United States, Spain, Canada
# Fabrizio Copano: Solo pienso en mi                                          Chile
# ...                                                                           ...
# Frank and Cindy                                                     United States
# Frank and Cindy                                                     United States
# Iverson                                                             United States
# Jeremy Scott: The People's Designer                                 United States
# Little Baby Bum: Nursery Rhyme Friends                                        NaN
#
#                                                                 director  \
# title
# Norm of the North: King Sized Adventure         Richard Finn, Tim Maltby
# Jandino: Whatever it Takes                                           NaN
# #realityhigh                                            Fernando Lebrija
# Automata                                                     Gabe Ibáñez
# Fabrizio Copano: Solo pienso en mi       Rodrigo Toro, Francisco Schultz
# ...                                                                  ...
# Frank and Cindy                                         G.J. Echternkamp
# Frank and Cindy                                         G.J. Echternkamp
# Iverson                                                   Zatella Beatty
# Jeremy Scott: The People's Designer                           Vlad Yudin
# Little Baby Bum: Nursery Rhyme Friends                               NaN
#
#                                          release_year rating
# title
# Norm of the North: King Sized Adventure          2019  TV-PG
# Jandino: Whatever it Takes                       2016  TV-MA
# #realityhigh                                     2017  TV-14
# Automata                                         2014      R
# Fabrizio Copano: Solo pienso en mi               2017  TV-MA
# ...                                               ...    ...
# Frank and Cindy                                  2007  TV-MA
# Frank and Cindy                                  2015      R
# Iverson                                          2014     NR
# Jeremy Scott: The People's Designer              2015  PG-13
# Little Baby Bum: Nursery Rhyme Friends           2016    NaN
#
# [4265 rows x 5 columns]

# %%
cleaned_other_movies.set_index(['title'])
# Out:
#                                                                              genres  \
# title
# Avatar                                              Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End                   Action|Adventure|Fantasy
# Spectre                                                   Action|Adventure|Thriller
# The Dark Knight Rises                                               Action|Thriller
# Star Wars: Episode VII - The Force Awakens     ...                      Documentary
# ...                                                                             ...
# Signed Sealed Delivered                                                Comedy|Drama
# The Following                                          Crime|Drama|Mystery|Thriller
# A Plague So Pleasant                                          Drama|Horror|Thriller
# Shanghai Calling                                               Comedy|Drama|Romance
# My Date with Drew                                                       Documentary
#
#                                                              director  \
# title
# Avatar                                                  James Cameron
# Pirates of the Caribbean: At World's End               Gore Verbinski
# Spectre                                                    Sam Mendes
# The Dark Knight Rises                               Christopher Nolan
# Star Wars: Episode VII - The Force Awakens     ...        Doug Walker
# ...                                                               ...
# Signed Sealed Delivered                                   Scott Smith
# The Following                                                     NaN
# A Plague So Pleasant                                 Benjamin Roberds
# Shanghai Calling                                          Daniel Hsia
# My Date with Drew                                            Jon Gunn
#
#                                                     release_year country  \
# title
# Avatar                                                    2009.0     USA
# Pirates of the Caribbean: At World's End                  2007.0     USA
# Spectre                                                   2015.0      UK
# The Dark Knight Rises                                     2012.0     USA
# Star Wars: Episode VII - The Force Awakens     ...           NaN     NaN
# ...                                                          ...     ...
# Signed Sealed Delivered                                   2013.0  Canada
# The Following                                                NaN     USA
# A Plague So Pleasant                                      2013.0     USA
# Shanghai Calling                                          2012.0     USA
# My Date with Drew                                         2004.0     USA
#
#                                                          budget        gross  \
# title
# Avatar                                              237000000.0  760505847.0
# Pirates of the Caribbean: At World's End            300000000.0  309404152.0
# Spectre                                             245000000.0  200074175.0
# The Dark Knight Rises                               250000000.0  448130642.0
# Star Wars: Episode VII - The Force Awakens     ...          NaN          NaN
# ...                                                         ...          ...
# Signed Sealed Delivered                                     NaN          NaN
# The Following                                               NaN          NaN
# A Plague So Pleasant                                     1400.0          NaN
# Shanghai Calling                                            NaN      10443.0
# My Date with Drew                                        1100.0      85222.0
#
#                                                     imdb_score rating
# title
# Avatar                                                     7.9  PG-13
# Pirates of the Caribbean: At World's End                   7.1  PG-13
# Spectre                                                    6.8  PG-13
# The Dark Knight Rises                                      8.5  PG-13
# Star Wars: Episode VII - The Force Awakens     ...         7.1    NaN
# ...                                                        ...    ...
# Signed Sealed Delivered                                    7.7    NaN
# The Following                                              7.5  TV-14
# A Plague So Pleasant                                       6.3    NaN
# Shanghai Calling                                           6.3  PG-13
# My Date with Drew                                          6.6     PG
#
# [5043 rows x 8 columns]

# %%
cleaned_netflix.to_csv(r'cleaned_netflix.csv')

# %%
cleaned_other_movies.to_csv(r'cleaned_other_movies.csv')
